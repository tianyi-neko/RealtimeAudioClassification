# %% [markdown]
# ## Install Libraries
#
# We will install the software libraries necessary for this week's tutorials, and test them to make sure they work.
#
# If you have never used a command-line or terminal before, [the linked wiki page will help you](https://github.com/DavidGoedicke/RealtimeAudioClassification/wiki/Command-lines-and-terminals-a-quick-introduction.md)
#
# Install [NumPy](https://en.wikipedia.org/wiki/NumPy) (Python support for large, multi-dimensional arrays and matrices ): ```conda install -c conda-forge numpy ```
# Install [MatplotLib](https://matplotlib.org) (Python 2D plotting library ): ```conda install -c conda-forge matplotlib ```
# Install [NumPy Ringbuffer](https://pypi.org/project/numpy_ringbuffer/) (Ringbuffer Data structure library ) ```pip install numpy_ringbuffer```
# Install [pyTorch](https://pytorch.org/get-started/locally/) (Python Machine Learning Library ): ```conda install pytorch torchvision -c pytorch```
# Install [opencv2](https://opencv.org) (Computer Vision library) : ```conda install -c conda-forge  opencv=3.4.1```
# Install [sklearn](https://scikit-learn.org/stable/) (SciKit Machine Learning library): ```conda install scikit-learn```
# Install [librosa](https://librosa.github.io/librosa/) (Music and Audio analysis library ): ```conda install -c conda-forge librosa ```
# Install [PyAudio](https://people.csail.mit.edu/hubert/pyaudio/) (Python bindings for PortAudio, the cross-platform audio I/O library ) : ```conda install -c anaconda pyaudio```

# %% [markdown]
# ## Test setup
#
# In the code below, we load ("import") the libraries that we just installed above, to make sure that Python can find the libraries.

# %%
import csv
import os
import wave
import time
import multiprocessing
from threading import Thread
import os
print("Found all built-in libraries.")
import numpy as np
from numpy_ringbuffer import RingBuffer
import matplotlib.pyplot as plt
print("Found all math libraries.")
import pyaudio
import librosa
print("Found all audio libraries.")
import torch
from torchvision import datasets, transforms, models
from sklearn.metrics import confusion_matrix
print("Found all machine learning libraries.")
import cv2
print("Found the computer vision library.")

# %% [markdown]
# If the above code runs without a problem, all libraries have installed and can be loaded. While it does not gurantee that everything will work, this is a very good sign.

# %%
conda install -c conda-forge  opencv=3.4.1
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed
# Initial quick solve with frozen env failed.  Unfreezing env and trying again.
# Solving environment: failed
#
# UnsatisfiableError: The following specifications were found to be incompatible with each other:
#
#
#
# Package libcxx conflicts for:
# pysoundfile -> numpy -> mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> python[version='>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# parso -> python[version='>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# imageio -> numpy -> mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> python[version='>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# sympy -> setuptools -> certifi[version='>=2016.09'] -> python[version='2.7.*,3.5.*,3.6.*,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# pyodbc -> python[version='3.6.*,>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# py -> python[version='2.7.*,3.4.*,3.6.*,>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# pytest-openfiles -> pytest[version='>=2.8.0,>=3.1'] -> attrs[version='>=17.2.0,>=17.4.0'] -> python[version='2.7.*,3.5.*,3.6.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# curl -> libcurl==7.63.0=h051b688_0 -> krb5[version='>=1.16.1,<1.17.0a0,>=1.16.2,<1.17.0a0'] -> libedit[version='>=3.1.20170329,<4.0a0'] -> ncurses[version='5.9,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# numpy -> mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> python[version='>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# zipp -> python[version='>=2.7,<2.8.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# pip -> wheel -> setuptools -> certifi[version='>=2016.09'] -> python[version='2.7.*,3.4.*,3.5.*,3.6.*,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# idna -> python[version='3.5.*,>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# beautifulsoup4 -> soupsieve -> setuptools -> certifi[version='>=2016.09'] -> python[version='2.7.*,3.5.*,3.6.*,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# xlwings -> psutil[version='>=2.0'] -> python[version='2.7.*,3.5.*,3.6.*,>=2.7,<2.8.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# snappy -> libcxx[version='>=4.0.1']
# curl -> libcurl==7.64.0=h76de61e_0 -> krb5[version='>=1.16.1,<1.17.0a0,>=1.16.2,<1.17.0a0'] -> libedit[version='>=3.1.20170329,<4.0a0'] -> ncurses[version='5.9,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# olefile -> python[version='2.7.*,3.5.*,3.6.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# pytables -> numexpr -> numpy[version='1.11.*,1.13.*,>=1.11.3,<2.0a0,>=1.8,>=1.9.3,<2.0a0'] -> mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> python[version='>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# matplotlib -> numpy=1.10 -> mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> python[version='>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# backports.os -> future -> python[version='>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# pyopenssl -> cryptography[version='>=1.3.4,>=1.9,>=2.2.1'] -> cffi[version='>=1.7'] -> pycparser -> python[version='3.6.*,>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# xlrd -> python[version='2.7.*,3.5.*,3.6.*,>=3.6,<3.7.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# ptyprocess -> python[version='2.7.*,>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# pycosat -> python[version='2.7.*,3.4.*,3.5.*,>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# statsmodels -> patsy[version='>=0.4.0'] -> scipy -> numpy[version='1.10.*,1.11.*,1.12.*,>=1.11.3,<2.0a0,>=1.9.3,<2.0a0'] -> mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> python[version='>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# traitlets -> six -> python[version='2.7.*,3.4.*,3.5.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# pycurl -> curl[version='>=7.55.1,<8.0a0'] -> libcurl==7.60.0=hf30b1f0_0 -> krb5[version='>=1.16.1,<1.17.0a0,>=1.16.2,<1.17.0a0'] -> libedit[version='>=3.1.20170329,<4.0a0'] -> ncurses[version='5.9,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# wrapt -> python[version='2.7.*,3.5.*,>=2.7,<2.8.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# mistune -> python[version='2.7.*,3.5.*,3.6.*,>=2.7,<2.8.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# ipython -> prompt_toolkit[version='>=1.0.3,<2.0.0,>=1.0.4,<2.0.0,>=2.0.0'] -> pygments -> setuptools -> certifi[version='>=2016.09'] -> python[version='2.7.*,3.5.*,3.6.*,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# pylint -> isort[version='>=4.2.5'] -> backports.functools_lru_cache -> setuptools -> certifi[version='>=2016.09'] -> python[version='2.7.*,3.4.*,3.5.*,3.6.*,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# pywavelets -> numpy[version='1.10.*,1.11.*,>=1.11.3,<2.0a0,>=1.9.3,<2.0a0'] -> mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> python[version='>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# scikit-learn -> scipy -> numpy[version='1.10.*,1.11.*,1.12.*,>=1.11.3,<2.0a0,>=1.9.3,<2.0a0'] -> mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> python[version='>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# prometheus_client -> twisted -> service_identity[version='>=18.1.0'] -> attrs[version='>=16.0.0'] -> python[version='2.7.*,3.5.*,3.6.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# send2trash -> python[version='>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# alabaster -> python[version='2.7.*,>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# libarchive -> zstd[version='>=1.3.3,<1.3.4.0a0,>=1.3.7,<1.3.8.0a0'] -> lz4 -> python[version='>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# gevent -> cffi[version='>=1.11.5,>=1.3.0'] -> pycparser -> python[version='3.6.*,>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# cloudpickle -> python[version='>=2.7,<2.8.0a0,>=3.6,<3.7.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# pcre -> libcxx[version='>=4.0.1']
# locket -> python[version='2.7.*,3.4.*,3.5.*,3.6.*,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# openpyxl -> jdcal -> python[version='2.7.*,3.6.*,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# pycrypto -> python[version='2.7.*,3.4.*,3.5.*,3.6.*,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# anaconda-client -> nbformat[version='>=4.4.0'] -> jupyter_core -> traitlets -> six -> python[version='2.7.*,3.4.*,3.5.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# prompt_toolkit -> pygments -> setuptools -> certifi[version='>=2016.09'] -> python[version='2.7.*,3.4.*,3.5.*,3.6.*,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# mkl-service -> numpy[version='>=1.11.3,<2.0a0'] -> mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> python[version='>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# libcxx
# libsndfile -> libflac -> gettext[version='>=0.19.8.1,<1.0a0'] -> libffi[version='>=3.2.1,<3.3.0a0,>=3.2.1,<4.0a0'] -> libcxx[version='>=4.0.1']
# python.app -> python[version='>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# scipy -> numpy[version='1.10.*,1.11.*,1.12.*,>=1.11.3,<2.0a0,>=1.9.3,<2.0a0'] -> mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> python[version='>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# sphinxcontrib -> python[version='>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# icu -> libcxx[version='>=4.0.1']
# cython -> setuptools -> certifi[version='>=2016.09'] -> python[version='2.7.*,3.4.*,3.5.*,3.6.*,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# networkx -> setuptools -> certifi[version='>=2016.09'] -> python[version='2.7.*,3.4.*,3.5.*,3.6.*,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# jupyter_core -> traitlets -> six -> python[version='2.7.*,3.4.*,3.5.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# pytz -> python[version='3.4.*,3.6.*,>=3.5,<3.6.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# pickleshare -> pathlib2 -> six -> python[version='2.7.*,3.4.*,3.5.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# pep8 -> python[version='3.5.*,>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# pycodestyle -> python[version='3.4.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# sphinxcontrib-jsmath -> python[version='>=3.5'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# conda-verify -> jinja2 -> setuptools -> certifi[version='>=2016.09'] -> python[version='2.7.*,3.4.*,3.5.*,3.6.*,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# qtawesome -> six -> python[version='2.7.*,3.4.*,3.5.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# importlib_metadata -> pathlib2 -> six -> python[version='2.7.*,3.4.*,3.5.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# sphinxcontrib-htmlhelp -> python[version='>=3.5'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# pytorch -> numpy[version='>=1.11'] -> mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# ipywidgets -> notebook -> prometheus_client -> twisted -> service_identity[version='>=18.1.0'] -> attrs[version='>=16.0.0'] -> python[version='2.7.*,3.5.*,3.6.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# jupyter -> notebook -> prometheus_client -> twisted -> service_identity[version='>=18.1.0'] -> attrs[version='>=16.0.0'] -> python[version='2.7.*,3.5.*,3.6.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# flask -> jinja2[version='>=2.10,>=2.4'] -> setuptools -> certifi[version='>=2016.09'] -> python[version='2.7.*,3.4.*,3.5.*,3.6.*,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# pycparser -> python[version='3.4.*,3.6.*,>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# sqlalchemy -> python[version='3.5.*,>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# rope -> python[version='2.7.*,3.6.*,>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# zeromq -> libcxx[version='>=4.0.1']
# urllib3 -> pyopenssl[version='>=0.14'] -> cryptography[version='>=1.3.4,>=1.9,>=2.2.1'] -> cffi[version='>=1.7'] -> pycparser -> python[version='3.4.*,3.6.*,>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# werkzeug -> python[version='3.4.*,3.5.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# simplegeneric -> python[version='2.7.*,3.6.*,>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# jupyter_console -> ipykernel -> ipython[version='>=4.0,>=5.0'] -> prompt_toolkit[version='>=1.0.3,<2.0.0,>=1.0.4,<2.0.0,>=2.0.0'] -> pygments -> setuptools -> certifi[version='>=2016.09'] -> python[version='2.7.*,3.5.*,3.6.*,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# mccabe -> python[version='3.4.*,3.5.*,3.6.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# anaconda-navigator -> anaconda-project[version='>=0.4'] -> anaconda-client -> nbformat[version='>=4.4.0'] -> jupyter_core -> traitlets -> six -> python[version='2.7.*,3.5.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# babel -> pytz -> python[version='3.4.*,3.6.*,>=3.5,<3.6.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# soupsieve -> backports.functools_lru_cache -> setuptools -> certifi[version='>=2016.09'] -> python[version='2.7.*,3.6.*,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# numpydoc -> sphinx -> pygments[version='>=2.0'] -> setuptools -> certifi[version='>=2016.09'] -> python[version='2.7.*,3.4.*,3.5.*,3.6.*,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# python-dateutil -> six[version='>=1.5'] -> python[version='2.7.*,3.4.*,3.5.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# click -> python[version='2.7.*,3.5.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# contextlib2 -> python[version='2.7.*,3.4.*,3.5.*,3.6.*,>=3.5,<3.6.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# appscript -> python[version='>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# conda-package-handling -> tqdm -> python[version='3.5.*,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# cytoolz -> toolz[version='>=0.10.0,>=0.8.0'] -> python[version='2.7.*,3.5.*,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# liblief -> libcxx[version='>=4.0.1']
# future -> python[version='>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# opencv=3.4.1 -> py-opencv==3.4.1=py37h1cf3a48_3 -> numpy[version='>=1.11.3,<2.0a0,>=1.9.3,<2.0a0'] -> mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> python[version='>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# ninja -> python[version='>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# backports -> python[version='2.7.*,>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# html5lib -> webencodings -> python[version='3.5.*,3.6.*,>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# hdf5 -> mpich[version='>=3.2,<3.3.0a0'] -> libcxx[version='>=4.0.1']
# scikit-image -> dask[version='>=0.5'] -> distributed[version='>=1.16.0,>=1.19.0,>=1.23.3'] -> bokeh[version='>=0.12.3'] -> numpy[version='>=1.7.1'] -> mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> python[version='>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# bitarray -> python[version='2.7.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# packaging -> six -> python[version='2.7.*,3.4.*,3.5.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# blosc -> snappy[version='>=1.1.7,<2.0a0'] -> libcxx[version='>=4.0.1']
# wheel -> setuptools -> certifi[version='>=2016.09'] -> python[version='2.7.*,3.4.*,3.5.*,3.6.*,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# nose -> setuptools -> certifi[version='>=2016.09'] -> python[version='2.7.*,3.4.*,3.5.*,3.6.*,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# nltk -> scikit-learn -> scipy -> numpy[version='1.10.*,1.11.*,1.12.*,>=1.11.3,<2.0a0,>=1.9.3,<2.0a0'] -> mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> python[version='>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# json5 -> python -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# mpfr -> gmp[version='>=6.1.2,>=6.1.2,<7.0a0'] -> libcxx[version='>=4.0.1']
# cycler -> six -> python[version='2.7.*,3.4.*,3.5.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# defusedxml -> python[version='2.7.*,3.4.*,3.6.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# pytest-doctestplus -> pytest[version='>=2.8'] -> attrs[version='>=17.2.0,>=17.4.0'] -> python[version='2.7.*,3.5.*,3.6.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# jupyter_client -> tornado[version='>=4.1'] -> ssl_match_hostname -> backports -> python[version='2.7.*,>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# backports.functools_lru_cache -> setuptools -> certifi[version='>=2016.09'] -> python[version='2.7.*,3.4.*,3.5.*,3.6.*,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# pycurl -> curl[version='>=7.55.1,<8.0a0'] -> libcurl==7.61.1=h76de61e_1002 -> krb5[version='>=1.16.1,<1.17.0a0,>=1.16.2,<1.17.0a0'] -> libedit[version='>=3.1.20170329,<4.0a0'] -> ncurses[version='5.9,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# sphinxcontrib-websupport -> sphinxcontrib -> python[version='>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# get_terminal_size -> backports.shutil_get_terminal_size -> backports -> python[version='2.7.*,>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# psutil -> python[version='2.7.*,3.5.*,3.6.*,>=2.7,<2.8.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# lazy-object-proxy -> python[version='2.7.*,3.6.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# nbconvert -> nbformat[version='>=4.4'] -> jupyter_core -> traitlets -> six -> python[version='2.7.*,3.4.*,3.5.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# xlsxwriter -> python[version='>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# wurlitzer -> python[version='>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# imagesize -> python[version='2.7.*,3.4.*,3.5.*,>=2.7,<2.8.0a0,>=3.5,<3.6.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# gnutls -> nettle[version='3.3.*,3.3|3.3.*,>=3.3,<3.4.0a0,>=3.4.1,>=3.4.1,<3.5.0a0'] -> gmp[version='6.1.*,>=6.1.2,<7.0a0'] -> libcxx[version='>=4.0.1']
# spyder -> spyder-kernels[version='0.*,>=0.4.2,<1,>=0.5.0,<1'] -> ipykernel[version='>4.9.0,>=4.8.2'] -> ipython[version='>=4.0,>=5.0'] -> prompt_toolkit[version='>=1.0.3,<2.0.0,>=1.0.4,<2.0.0,>=2.0.0'] -> pygments -> setuptools -> certifi[version='>=2016.09'] -> python[version='2.7.*,3.5.*,3.6.*,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# sip -> python[version='3.6.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# gmpy2 -> python[version='3.5.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# gmp -> libcxx[version='>=4.0.1']
# ruamel_yaml -> python[version='3.5.*,>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# sphinxcontrib-serializinghtml -> python[version='>=3.5'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# joblib -> python[version='3.4.*,3.5.*,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# patsy -> scipy -> numpy[version='1.10.*,1.11.*,1.12.*,>=1.11.3,<2.0a0,>=1.9.3,<2.0a0'] -> mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> python[version='>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# more-itertools -> six[version='>=1.0.0,<2.0.0'] -> python[version='2.7.*,3.4.*,3.5.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# qtconsole -> ipykernel[version='>=4.1'] -> ipython[version='>=4.0,>=5.0'] -> prompt_toolkit[version='>=1.0.3,<2.0.0,>=1.0.4,<2.0.0,>=2.0.0'] -> pygments -> setuptools -> certifi[version='>=2016.09'] -> python[version='2.7.*,3.5.*,3.6.*,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# navigator-updater -> pyqt[version='>=5.6'] -> sip[version='4.18,4.18.*,>=4.19.4,<=4.19.8'] -> python[version='3.6.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# _ipyw_jlab_nb_ext_conf -> ipywidgets -> notebook -> prometheus_client -> twisted -> service_identity[version='>=18.1.0'] -> attrs[version='>=16.0.0'] -> python[version='2.7.*,3.5.*,3.6.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# pycurl -> curl[version='>=7.55.1,<8.0a0'] -> libcurl==7.62.0=hbdb9355_0 -> krb5[version='>=1.16.1,<1.17.0a0,>=1.16.2,<1.17.0a0'] -> libedit[version='>=3.1.20170329,<4.0a0'] -> ncurses[version='5.9,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# sortedcontainers -> python[version='>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# pluggy -> python[version='2.7.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# qt -> sqlite[version='>=3.22.0,<4.0a0,>=3.24.0,<4.0a0,>=3.25.3,<4.0a0,>=3.26.0,<4.0a0,>=3.28.0,<4.0a0,>=3.29.0,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# conda-build -> conda[version='>=4.3'] -> pyopenssl[version='>=16.2.0'] -> cryptography[version='>=1.3.4,>=1.9,>=2.2.1'] -> cffi[version='>=1.7'] -> pycparser -> python[version='3.4.*,3.6.*,>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# mpc -> mpfr[version='3.*,>=4.0.1,<5.0a0'] -> gmp[version='>=6.1.2,>=6.1.2,<7.0a0'] -> libcxx[version='>=4.0.1']
# nbformat -> jupyter_core -> traitlets -> six -> python[version='2.7.*,3.4.*,3.5.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# conda[version='>=4.7.10'] -> pyopenssl[version='>=16.2.0'] -> cryptography[version='>=1.3.4,>=1.9,>=2.2.1'] -> cffi[version='>=1.7'] -> pycparser -> python[version='3.6.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# greenlet -> python[version='2.7.*,>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# attrs -> hypothesis -> coverage -> python[version='2.7.*,3.5.*,3.6.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# resampy -> scipy[version='>=0.13'] -> numpy[version='1.10.*,1.11.*,1.12.*,>=1.11.3,<2.0a0,>=1.9.3,<2.0a0'] -> mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> python[version='>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# distributed -> dask[version='>=0.13.0'] -> numpy[version='>=1.10,>=1.11.0'] -> mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> python[version='>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# pathlib2 -> six -> python[version='2.7.*,3.4.*,3.5.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# jupyterlab_server -> notebook -> prometheus_client -> twisted -> service_identity[version='>=18.1.0'] -> attrs[version='>=16.0.0'] -> python[version='3.5.*,3.6.*,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# librosa -> scikit-learn[version='>=0.14.0,>=0.14.0,!=0.19.0,>=0.19.1'] -> scipy -> numpy[version='1.10.*,1.11.*,1.12.*,>=1.11.3,<2.0a0,>=1.9.3,<2.0a0'] -> mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> python[version='>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# mkl_random -> numpy[version='>=1.11.3,<2.0a0,>=1.9.3,<2.0a0'] -> mkl_fft[version='>=1.0.4'] -> mkl-service[version='>=2,<3.0a0'] -> six -> python[version='2.7.*,3.5.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# llvm-openmp -> libcxx[version='>=4.0.1']
# entrypoints -> configparser -> backports -> python[version='2.7.*,>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# ...
# ffmpeg -> x264[version='1!152.*,>=1!152.20180717,<1!153'] -> libgcc -> mpc[version='>=0.8.0'] -> mpfr[version='3.*,>=4.0.1,<5.0a0'] -> gmp[version='>=6.1.2,>=6.1.2,<7.0a0'] -> libcxx[version='>=4.0.1']
# fastcache -> python[version='>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# itsdangerous -> python[version='2.7.*,3.4.*,3.6.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# toolz -> python[version='2.7.*,3.5.*,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# qtpy -> python[version='>=2.7,<2.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# pytest-remotedata -> pytest[version='>=3.1'] -> attrs[version='>=17.2.0,>=17.4.0'] -> python[version='2.7.*,3.5.*,3.6.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# testpath -> pathlib2 -> six -> python[version='2.7.*,3.4.*,3.5.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# colorama -> python[version='2.7.*,3.4.*,3.5.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# bkcharts -> numpy[version='>=1.7.1'] -> mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> python[version='>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# sphinxcontrib-devhelp -> python[version='>=3.5'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# widgetsnbextension -> notebook[version='>=4.4.1'] -> prometheus_client -> twisted -> service_identity[version='>=18.1.0'] -> attrs[version='>=16.0.0'] -> python[version='2.7.*,3.5.*,3.6.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# path.py -> importlib_metadata[version='>=0.5'] -> pathlib2 -> six -> python[version='2.7.*,3.4.*,3.5.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# docutils -> python[version='2.7.*,3.6.*,>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# atomicwrites -> python[version='>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# openh264 -> libcxx[version='>=4.0.1']
# opencv=3.4.1 -> py-opencv==3.4.1=py37h4b7e113_3 -> numpy[version='>=1.11.3,<2.0a0,>=1.9.3,<2.0a0'] -> mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> python[version='>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# libxslt -> libxml2[version='2.9.*,>=2.9.4,<2.10.0a0,>=2.9.9,<2.10.0a0'] -> icu[version='56.*,58.*,>=58.2,<59.0a0'] -> libcxx[version='>=4.0.1']
# torchvision -> pytorch[version='>=1.1.0'] -> numpy[version='>=1.11'] -> mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# bokeh -> numpy[version='>=1.7.1'] -> mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> python[version='>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# certifi -> python[version='2.7.*,3.4.*,3.5.*,3.6.*,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# sphinx -> pygments[version='>=2.0'] -> setuptools -> certifi[version='>=2016.09'] -> python[version='2.7.*,3.4.*,3.5.*,3.6.*,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# opencv=3.4.1 -> py-opencv==3.4.1=py35h9d9193e_1 -> numpy[version='>=1.11.3,<2.0a0,>=1.9.3,<2.0a0'] -> mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> python[version='>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# dbus -> glib[version='>=2.53.6,<2.54.0a0,>=2.56.1,<2.57.0a0'] -> gettext[version='>=0.19.8.1,<1.0a0'] -> libffi[version='>=3.2.1,<3.3.0a0,>=3.2.1,<4.0a0'] -> libcxx[version='>=4.0.1']
# sqlite -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# zict -> heapdict -> python[version='3.5.*,>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# pysocks -> python[version='2.7.*,3.5.*,>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# numba -> numpy[version='>=1.10,<1.11.0a0,>=1.11,<1.12.0a0,>=1.11.3,<2.0a0,>=1.13,<1.14.0a0,>=1.14,<1.15.0a0,>=1.9.3,<2.0a0'] -> mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> python[version='>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# ipython_genutils -> python[version='2.7.*,3.4.*,3.5.*,3.6.*,>=3.5,<3.6.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# mpmath -> gmpy2 -> python[version='3.5.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# pyflakes -> python[version='2.7.*,3.4.*,3.5.*,>=2.7,<2.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# expat -> libcxx[version='>=4.0.1']
# llvmlite -> python[version='>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# pyparsing -> python[version='2.7.*,3.4.*,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# bleach -> setuptools -> certifi[version='>=2016.09'] -> python[version='2.7.*,3.4.*,3.5.*,3.6.*,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# et_xmlfile -> python[version='2.7.*,>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# asn1crypto -> python[version='2.7.*,>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# pycurl -> curl[version='>=7.55.1,<8.0a0'] -> libcurl==7.64.0=h76de61e_0 -> krb5[version='>=1.16.1,<1.17.0a0,>=1.16.2,<1.17.0a0'] -> libedit[version='>=3.1.20170329,<4.0a0'] -> ncurses[version='5.9,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# dask-core -> python[version='>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# tornado -> ssl_match_hostname -> backports -> python[version='2.7.*,>=2.7,<2.8.0a0,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# ply -> python[version='2.7.*,3.5.*,3.6.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# libedit -> ncurses[version='5.9,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# h5py -> numpy[version='1.11.*,1.12.*,>=1.9.3,<2.0a0'] -> mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> python[version='>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# readline -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# tblib -> python[version='2.7.*,3.5.*,3.6.*,>=2.7,<2.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# sphinxcontrib-applehelp -> python[version='>=3.5'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# multipledispatch -> six -> python[version='2.7.*,3.4.*,3.5.*,>=2.7,<2.8.0a0,>=3.6,<3.7.0a0,>=3.7,<3.8.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# curl -> libcurl==7.61.1=h76de61e_1002 -> krb5[version='>=1.16.1,<1.17.0a0,>=1.16.2,<1.17.0a0'] -> libedit[version='>=3.1.20170329,<4.0a0'] -> ncurses[version='5.9,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# ncurses -> libcxx[version='>=4.0.1']
# libflac -> gettext[version='>=0.19.8.1,<1.0a0'] -> libffi[version='>=3.2.1,<3.3.0a0,>=3.2.1,<4.0a0'] -> libcxx[version='>=4.0.1']
# x264 -> libgcc -> mpc[version='>=0.8.0'] -> mpfr[version='3.*,>=4.0.1,<5.0a0'] -> gmp[version='>=6.1.2,>=6.1.2,<7.0a0'] -> libcxx[version='>=4.0.1']
# partd -> toolz -> python[version='2.7.*,3.5.*,>=3.5,<3.6.0a0,>=3.6,<3.7.0a0'] -> sqlite[version='3.13.*,>=3.20.1,<4.0a0,>=3.25.1,<4.0a0,>=3.25.3,<4.0a0,>=3.27.2,<4.0a0'] -> readline[version='7.0,>=7.0,<8.0a0'] -> ncurses[version='5.9.*,6.0.*,>=6.1,<6.2.0a0,>=6.1,<7.0a0'] -> libcxx[version='>=4.0.1']
# Package hdf5 conflicts for:
# opencv=3.4.1 -> py-opencv==3.4.1=py27h9d9193e_1 -> hdf5[version='>=1.10.2,<1.10.3.0a0,>=1.8.18,<1.8.19.0a0']
# opencv=3.4.1 -> py-opencv==3.4.1=py27ha6b5d2e_1 -> libopencv==3.4.1=h0f2e407_1 -> hdf5[version='>=1.10.2,<1.10.3.0a0,>=1.8.18,<1.8.19.0a0']
# opencv=3.4.1 -> py-opencv==3.4.1=py27h9d9193e_1 -> libopencv==3.4.1=he076b03_1 -> hdf5[version='>=1.10.2,<1.10.3.0a0,>=1.8.18,<1.8.19.0a0']
# opencv=3.4.1 -> py-opencv==3.4.1=py36h9d9193e_1 -> libopencv==3.4.1=h14a57ad_3 -> hdf5[version='>=1.10.2,<1.10.3.0a0,>=1.8.18,<1.8.19.0a0']
# opencv=3.4.1 -> py-opencv==3.4.1=py37h1cf3a48_3 -> libopencv==3.4.1=hd783f81_3 -> hdf5[version='>=1.10.2,<1.10.3.0a0,>=1.8.18,<1.8.19.0a0']
# opencv=3.4.1 -> py-opencv==3.4.1=py27ha6b5d2e_1 -> hdf5[version='>=1.10.2,<1.10.3.0a0,>=1.8.18,<1.8.19.0a0']
# opencv=3.4.1 -> py-opencv==3.4.1=py37h1cf3a48_3 -> hdf5[version='>=1.10.2,<1.10.3.0a0,>=1.8.18,<1.8.19.0a0']
# opencv=3.4.1 -> py-opencv==3.4.1=py36h9d9193e_1 -> hdf5[version='>=1.10.2,<1.10.3.0a0,>=1.8.18,<1.8.19.0a0']
# pytables -> hdf5[version='1.10.1,1.8.17|1.8.17.*,>=1.10.3,<1.10.4.0a0,>=1.10.4,<1.10.5.0a0,>=1.8.18,<1.8.19.0a0']
# h5py -> hdf5[version='1.10.1.*,1.8.17.*,>=1.10.1,<1.10.2.0a0,>=1.10.3,<1.10.4.0a0,>=1.10.4,<1.10.5.0a0',build=mpi_mpich_*]
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c https://conda.anaconda.org/menpo opencv3
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with current_repodata.json, will retry with next repodata source.
# Initial quick solve with frozen env failed.  Unfreezing env and trying again.
# Solving environment: failed with current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: /
